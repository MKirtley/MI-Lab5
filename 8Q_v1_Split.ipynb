# %% [markdown]
# ### Importing jdc so I can run the functions outside of the class cell.

# %%
pip install jdc
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: jdc in /usr/local/lib/python3.7/dist-packages (0.0.9)

# %% [markdown]
# ### Importing required libraries

# %%
from __future__ import print_function, division
import numpy as np
from random import Random, random
import jdc

# %% [markdown]
# #### The State class. It keeps stack of the state, which is a list of 8 integers ranging from 1 to 8.
#
# #### The init function saves the class properties to memory and allows the parent values and the generation number to be passed in.
#
# #### If there are no parents, the state property initialises itself as a list of random numbers of length 8. If there are parents, they are assigned to the variables parent1 and parent2, set as the parents property, put through the crossover function and the mutate function is then ran with those arguments.

# %%
class State(object):
    MUTATION_RATE = 0.4 # Play with this value, higher value means more chance of mutation
    def __init__(self, parents=None, generation = 1):
        r = Random()
        self._fitness = None
        self._probability = None
        self.generation = generation

        if parents==None:
            self.parents = None
            self.state = [r.randint(1,8) for y in range(8)]

        else:            
            parent1 = parents[0]
            parent2 = parents[1]
            self.parents = parents
            self.state = self.crossover(parent1, parent2)
            self.mutate()

# %% [markdown]
# #### This is measuring the fitness score, which depends on the number of collisions between two queens.
#
# #### The state is passed in from the class property to the fitness function.
#
# #### It counts the number of times a number in the list matches with another number in the list and divides it by 2 (as two queens would match with each other). It also counts the number of diagonal collisions divided by 2.
#
# #### The fitness score is 28 (the maximum number of collisions) minus the sum of horizonal collisions + diagonal collisions.
#
# #### It saves the fitness score to the fitness property.
#
# #### A solution would have 0 collisions.

# %%
# %%add_to State
# def fitness(self):
#     if not self._fitness:
#         state = self.state
#
#         horizontal_collisions = sum([state.count(col)-1 for col in state])/2
#
#         diagonal_collisions = 0
#         for i, col in enumerate(state):
#             for j, diagonal in enumerate(state):
#                 mod = abs(i-j)
#                 if mod > 0: #we don't want to count the current queen in a collision with herself
#                     if diagonal + mod == col or diagonal - mod == col:
#                         diagonal_collisions += 1
#         diagonal_collisions /= 2 #we were counting the diagonal collisions double
#         self._fitness = int(28 - (horizontal_collisions + diagonal_collisions))
#     return self._fitness

# %% [markdown]
# #### This is giving each state a probability value based on it's fitness score. The better the fitness score, the higher the probability.

# %%
# %%add_to State
# def probability(self, population):
#     if not self._probability:
#         self._probability = self.fitness() / sum([x.fitness() for x in population])
#     return self._probability

# %% [markdown]
# #### The crossover function. This is calling in parent 1 and parent 2 and returning a child that has the values of a random split between then.

# %%
# %%add_to State
# def crossover(self, parent1, parent2):
#     r = Random()
#     crossover_index = r.randint(0,8)
#     left = parent1.state[0:crossover_index]
#
#     right = parent2.state[crossover_index:8]
#     left.extend(right)
#     return left

# %% [markdown]
# #### The mutate function. For each state, each value has a random chance (depending on MUTATION_RATE) to change one of it's values to a random value between 1 and 8.

# %%
# %%add_to State
# def mutate(self):
#     r = Random()
#     for i in range(len(self.state)):
#         if random() < State.MUTATION_RATE:
#             self.state[i] = r.randint(1,8)

# %% [markdown]
# #### A string representation of the state. This creates a chessboard visualisation of the list in self.state.

# %%
# %%add_to State
# def __str__(self):
#
#     queen_symbol = '♛'
#     blank_white_symbol = '▧'
#     blank_black_symbol = '☐'
#
#     # _state = np.zeros((8,8), dtype = np.uint8)
#     # Create a blank board with alternating 0 and 1
#     _i = np.sum(np.indices((8,8)), axis = 0)
#     _state = np.where(_i % 2 == 0, 0, 1)
#
#     for i, j in enumerate(self.state):
#         _state[j - 1, i] = 2
#
#     _repr = "Generation: " + str(self.generation) + "\nFitness: " + str(self.fitness()) + "\n" + str(self.state) +  "\n"
#     for h in range(8):
#         for w in range(8):
#             _repr += ([blank_white_symbol, blank_black_symbol, queen_symbol][_state[h, w]] + " ")
#         _repr += "\n"
#     return _repr

# %% [markdown]
# #### Picking random states from the population. The states that are picked must have a lower probability score than the random function. Keeping the population as the same number.

# %%
# %%add_to State
# def pickRandomByProbability(populationByProbability):
#     i = 0
#     selectedState = None
#     while selectedState == None:
#         current = populationByProbability[i]
#         if current[0] <= random():
#             return current[1]
#         if i+1 <= len(populationByProbability):
#             i = 0
#         else:
#             i += 1

# %% [markdown]
# #### Creating a new population. The states that have a lower probability score (fitness / the sum of all fitness scores)  have an increased chance of becoming parents in the next population.

# %%
# %%add_to State
# def generateNextPopulation(population, n):
#     newPopulation = []
#     while len(newPopulation) < n:
#         populationByProbability = [(x.probability(population), x) for x in population]
#         parent1 = pickRandomByProbability(populationByProbability)
#         populationByProbability = [x for x in populationByProbability if x[1] != parent1]
#         parent2 = pickRandomByProbability(populationByProbability)
#         newPopulation.append(State((parent1, parent2), generation = parent1.generation + 1))
#     return newPopulation

# %% [markdown]
# #### The main function. This sets the initial values and creates a population list. When a fitness score of 28 has been reached, it shows the solution state. If none of the states in the population have a fitness score of 28, a new population is generated, and it shows the generation number, as well as the state with the max fitness score.

# %%
# %%add_to State
# def main():
#     populationSize = 100
#     generation = 1
#     population = [State(generation = generation) for x in range(populationSize)]
#
#     while not 28 in [x.fitness() for x in population]:
#         print("generation %d Max fitness: %d" % (generation, max([x.fitness() for x in population])))
#         population = generateNextPopulation(population, populationSize)
#         generation += 1
#
#     for x in population:
#         if x.fitness() == 28:
#             if x.parents is not None:
#                 print("Parents::")
#                 print(x.parents[0])
#                 print(x.parents[1])
#             print("Solution state: ")
#             print(x)

# %% [markdown]
# #### Runs the main function

# %%
if __name__ == '__main__':
    main()
# Out:
# generation 1 Max fitness: 25
# generation 2 Max fitness: 24
# generation 3 Max fitness: 25
# generation 4 Max fitness: 25
# generation 5 Max fitness: 24
# generation 6 Max fitness: 25
# generation 7 Max fitness: 25
# generation 8 Max fitness: 25
# generation 9 Max fitness: 24
# generation 10 Max fitness: 25
# generation 11 Max fitness: 25
# generation 12 Max fitness: 24
# generation 13 Max fitness: 24
# generation 14 Max fitness: 27
# generation 15 Max fitness: 25
# generation 16 Max fitness: 25
# generation 17 Max fitness: 24
# generation 18 Max fitness: 25
# generation 19 Max fitness: 25
# generation 20 Max fitness: 25
# generation 21 Max fitness: 24
# generation 22 Max fitness: 26
# generation 23 Max fitness: 24
# generation 24 Max fitness: 25
# generation 25 Max fitness: 24
# generation 26 Max fitness: 25
# generation 27 Max fitness: 24
# generation 28 Max fitness: 24
# generation 29 Max fitness: 25
# generation 30 Max fitness: 25
# generation 31 Max fitness: 24
# generation 32 Max fitness: 25
# generation 33 Max fitness: 25
# generation 34 Max fitness: 24
# generation 35 Max fitness: 25
# generation 36 Max fitness: 27
# generation 37 Max fitness: 25
# generation 38 Max fitness: 25
# generation 39 Max fitness: 24
# generation 40 Max fitness: 24
# generation 41 Max fitness: 25
# generation 42 Max fitness: 25
# generation 43 Max fitness: 26
# generation 44 Max fitness: 24
# generation 45 Max fitness: 25
# generation 46 Max fitness: 25
# generation 47 Max fitness: 25
# generation 48 Max fitness: 25
# generation 49 Max fitness: 25
# generation 50 Max fitness: 24
# generation 51 Max fitness: 25
# generation 52 Max fitness: 25
# generation 53 Max fitness: 26
# generation 54 Max fitness: 25
# generation 55 Max fitness: 26
# generation 56 Max fitness: 25
# generation 57 Max fitness: 25
# generation 58 Max fitness: 24
# generation 59 Max fitness: 25
# generation 60 Max fitness: 25
# generation 61 Max fitness: 25
# generation 62 Max fitness: 24
# generation 63 Max fitness: 25
# generation 64 Max fitness: 24
# generation 65 Max fitness: 23
# generation 66 Max fitness: 24
# generation 67 Max fitness: 26
# generation 68 Max fitness: 25
# generation 69 Max fitness: 25
# generation 70 Max fitness: 26
# generation 71 Max fitness: 25
# generation 72 Max fitness: 25
# generation 73 Max fitness: 25
# generation 74 Max fitness: 25
# generation 75 Max fitness: 24
# generation 76 Max fitness: 25
# generation 77 Max fitness: 25
# generation 78 Max fitness: 26
# generation 79 Max fitness: 25
# generation 80 Max fitness: 26
# generation 81 Max fitness: 26
# generation 82 Max fitness: 25
# generation 83 Max fitness: 25
# generation 84 Max fitness: 25
# generation 85 Max fitness: 26
# generation 86 Max fitness: 25
# generation 87 Max fitness: 25
# generation 88 Max fitness: 25
# generation 89 Max fitness: 25
# generation 90 Max fitness: 25
# generation 91 Max fitness: 24
# generation 92 Max fitness: 25
# generation 93 Max fitness: 26
# generation 94 Max fitness: 25
# generation 95 Max fitness: 25
# generation 96 Max fitness: 25
# generation 97 Max fitness: 26
# generation 98 Max fitness: 25
# generation 99 Max fitness: 25
# generation 100 Max fitness: 25
# generation 101 Max fitness: 26
# generation 102 Max fitness: 24
# generation 103 Max fitness: 25
# generation 104 Max fitness: 25
# generation 105 Max fitness: 26
# generation 106 Max fitness: 26
# generation 107 Max fitness: 25
# generation 108 Max fitness: 25
# generation 109 Max fitness: 24
# generation 110 Max fitness: 25
# generation 111 Max fitness: 26
# generation 112 Max fitness: 24
# generation 113 Max fitness: 26
# generation 114 Max fitness: 26
# generation 115 Max fitness: 25
# generation 116 Max fitness: 25
# generation 117 Max fitness: 25
# generation 118 Max fitness: 24
# generation 119 Max fitness: 25
# generation 120 Max fitness: 25
# generation 121 Max fitness: 25
# generation 122 Max fitness: 25
# generation 123 Max fitness: 25
# generation 124 Max fitness: 26
# generation 125 Max fitness: 25
# generation 126 Max fitness: 24
# generation 127 Max fitness: 26
# generation 128 Max fitness: 24
# generation 129 Max fitness: 25
# generation 130 Max fitness: 25
# generation 131 Max fitness: 26
# generation 132 Max fitness: 25
# generation 133 Max fitness: 25
# generation 134 Max fitness: 24
# generation 135 Max fitness: 25
# generation 136 Max fitness: 27
# generation 137 Max fitness: 24
# generation 138 Max fitness: 24
# generation 139 Max fitness: 24
# generation 140 Max fitness: 25
# generation 141 Max fitness: 26
# generation 142 Max fitness: 26
# generation 143 Max fitness: 25
# generation 144 Max fitness: 25
# generation 145 Max fitness: 26
# generation 146 Max fitness: 26
# generation 147 Max fitness: 26
# generation 148 Max fitness: 26
# generation 149 Max fitness: 25
# generation 150 Max fitness: 24
# generation 151 Max fitness: 26
# generation 152 Max fitness: 25
# generation 153 Max fitness: 23
# generation 154 Max fitness: 25
# generation 155 Max fitness: 25
# generation 156 Max fitness: 23
# generation 157 Max fitness: 24
# generation 158 Max fitness: 24
# generation 159 Max fitness: 23
# generation 160 Max fitness: 25
# generation 161 Max fitness: 25
# generation 162 Max fitness: 26
# generation 163 Max fitness: 25
# generation 164 Max fitness: 24
# generation 165 Max fitness: 26
# generation 166 Max fitness: 25
# generation 167 Max fitness: 25
# generation 168 Max fitness: 26
# generation 169 Max fitness: 25
# generation 170 Max fitness: 25
# generation 171 Max fitness: 25
# generation 172 Max fitness: 25
# generation 173 Max fitness: 25
# generation 174 Max fitness: 24
# generation 175 Max fitness: 25
# generation 176 Max fitness: 25
# generation 177 Max fitness: 25
# generation 178 Max fitness: 25
# generation 179 Max fitness: 26
# generation 180 Max fitness: 25
# generation 181 Max fitness: 24
# generation 182 Max fitness: 26
# generation 183 Max fitness: 24
# generation 184 Max fitness: 26
# generation 185 Max fitness: 24
# generation 186 Max fitness: 25
# generation 187 Max fitness: 25
# generation 188 Max fitness: 24
# generation 189 Max fitness: 25
# generation 190 Max fitness: 24
# generation 191 Max fitness: 24
# generation 192 Max fitness: 25
# generation 193 Max fitness: 26
# generation 194 Max fitness: 24
# generation 195 Max fitness: 25
# generation 196 Max fitness: 25
# generation 197 Max fitness: 24
# generation 198 Max fitness: 26
# generation 199 Max fitness: 25
# generation 200 Max fitness: 24
# generation 201 Max fitness: 25
# generation 202 Max fitness: 26
# generation 203 Max fitness: 25
# generation 204 Max fitness: 24
# generation 205 Max fitness: 24
# generation 206 Max fitness: 26
# generation 207 Max fitness: 25
# generation 208 Max fitness: 25
# generation 209 Max fitness: 25
# generation 210 Max fitness: 25
# generation 211 Max fitness: 25
# generation 212 Max fitness: 25
# generation 213 Max fitness: 24
# generation 214 Max fitness: 26
# generation 215 Max fitness: 25
# generation 216 Max fitness: 24
# generation 217 Max fitness: 25
# generation 218 Max fitness: 27
# generation 219 Max fitness: 25
# generation 220 Max fitness: 25
# generation 221 Max fitness: 24
# generation 222 Max fitness: 25
# generation 223 Max fitness: 23
# generation 224 Max fitness: 26
# generation 225 Max fitness: 25
# generation 226 Max fitness: 25
# generation 227 Max fitness: 25
# generation 228 Max fitness: 24
# generation 229 Max fitness: 25
# generation 230 Max fitness: 24
# generation 231 Max fitness: 24
# generation 232 Max fitness: 25
# generation 233 Max fitness: 24
# generation 234 Max fitness: 25
# generation 235 Max fitness: 24
# generation 236 Max fitness: 24
# generation 237 Max fitness: 24
# generation 238 Max fitness: 24
# generation 239 Max fitness: 26
# generation 240 Max fitness: 24
# generation 241 Max fitness: 26
# generation 242 Max fitness: 24
# generation 243 Max fitness: 23
# generation 244 Max fitness: 24
# generation 245 Max fitness: 25
# generation 246 Max fitness: 25
# generation 247 Max fitness: 25
# generation 248 Max fitness: 25
# generation 249 Max fitness: 24
# generation 250 Max fitness: 24
# generation 251 Max fitness: 24
# generation 252 Max fitness: 26
# generation 253 Max fitness: 24
# generation 254 Max fitness: 24
# generation 255 Max fitness: 25
# generation 256 Max fitness: 24
# generation 257 Max fitness: 25
# generation 258 Max fitness: 25
# generation 259 Max fitness: 26
# generation 260 Max fitness: 26
# generation 261 Max fitness: 25
# generation 262 Max fitness: 25
# generation 263 Max fitness: 24
# generation 264 Max fitness: 25
# generation 265 Max fitness: 25
# generation 266 Max fitness: 25
# generation 267 Max fitness: 24
# generation 268 Max fitness: 24
# generation 269 Max fitness: 25
# generation 270 Max fitness: 25
# generation 271 Max fitness: 25
# generation 272 Max fitness: 25
# generation 273 Max fitness: 25
# generation 274 Max fitness: 26
# generation 275 Max fitness: 25
# generation 276 Max fitness: 24
# generation 277 Max fitness: 24
# generation 278 Max fitness: 26
# generation 279 Max fitness: 26
# generation 280 Max fitness: 24
# generation 281 Max fitness: 24
# generation 282 Max fitness: 24
# generation 283 Max fitness: 25
# generation 284 Max fitness: 25
# generation 285 Max fitness: 25
# generation 286 Max fitness: 25
# generation 287 Max fitness: 26
# generation 288 Max fitness: 25
# generation 289 Max fitness: 26
# generation 290 Max fitness: 24
# generation 291 Max fitness: 25
# generation 292 Max fitness: 25
# generation 293 Max fitness: 24
# generation 294 Max fitness: 24
# generation 295 Max fitness: 23
# generation 296 Max fitness: 25
# generation 297 Max fitness: 25
# generation 298 Max fitness: 25
# generation 299 Max fitness: 25
# generation 300 Max fitness: 25
# generation 301 Max fitness: 26
# generation 302 Max fitness: 25
# generation 303 Max fitness: 25
# generation 304 Max fitness: 25
# generation 305 Max fitness: 25
# generation 306 Max fitness: 25
# generation 307 Max fitness: 25
# generation 308 Max fitness: 24
# generation 309 Max fitness: 26
# generation 310 Max fitness: 24
# generation 311 Max fitness: 24
# generation 312 Max fitness: 24
# generation 313 Max fitness: 26
# generation 314 Max fitness: 25
# generation 315 Max fitness: 25
# generation 316 Max fitness: 25
# generation 317 Max fitness: 25
# generation 318 Max fitness: 24
# generation 319 Max fitness: 25
# generation 320 Max fitness: 25
# generation 321 Max fitness: 25
# generation 322 Max fitness: 24
# generation 323 Max fitness: 24
# generation 324 Max fitness: 24
# generation 325 Max fitness: 24
# generation 326 Max fitness: 25
# generation 327 Max fitness: 24
# generation 328 Max fitness: 25
# generation 329 Max fitness: 25
# generation 330 Max fitness: 25
# generation 331 Max fitness: 25
# generation 332 Max fitness: 25
# generation 333 Max fitness: 26
# generation 334 Max fitness: 24
# generation 335 Max fitness: 24
# generation 336 Max fitness: 25
# generation 337 Max fitness: 26
# generation 338 Max fitness: 26
# generation 339 Max fitness: 26
# generation 340 Max fitness: 25
# generation 341 Max fitness: 24
# generation 342 Max fitness: 25
# generation 343 Max fitness: 25
# generation 344 Max fitness: 25
# generation 345 Max fitness: 24
# generation 346 Max fitness: 26
# generation 347 Max fitness: 26
# generation 348 Max fitness: 24
# generation 349 Max fitness: 25
# generation 350 Max fitness: 24
# generation 351 Max fitness: 25
# generation 352 Max fitness: 25
# generation 353 Max fitness: 25
# generation 354 Max fitness: 25
# generation 355 Max fitness: 24
# generation 356 Max fitness: 25
# generation 357 Max fitness: 25
# generation 358 Max fitness: 25
# generation 359 Max fitness: 25
# generation 360 Max fitness: 25
# generation 361 Max fitness: 26
# generation 362 Max fitness: 25
# generation 363 Max fitness: 26
# generation 364 Max fitness: 26
# generation 365 Max fitness: 25
# generation 366 Max fitness: 26
# generation 367 Max fitness: 25
# generation 368 Max fitness: 25
# generation 369 Max fitness: 25
# generation 370 Max fitness: 26
# generation 371 Max fitness: 24
# generation 372 Max fitness: 26
# generation 373 Max fitness: 25
# generation 374 Max fitness: 25
# generation 375 Max fitness: 25
# generation 376 Max fitness: 25
# generation 377 Max fitness: 25
# generation 378 Max fitness: 25
# generation 379 Max fitness: 26
# generation 380 Max fitness: 25
# generation 381 Max fitness: 24
# generation 382 Max fitness: 24
# generation 383 Max fitness: 25
# generation 384 Max fitness: 25
# generation 385 Max fitness: 25
# generation 386 Max fitness: 24
# generation 387 Max fitness: 25
# generation 388 Max fitness: 24
# generation 389 Max fitness: 24
# generation 390 Max fitness: 25
# generation 391 Max fitness: 24
# generation 392 Max fitness: 25
# generation 393 Max fitness: 26
# generation 394 Max fitness: 25
# generation 395 Max fitness: 24
# generation 396 Max fitness: 25
# generation 397 Max fitness: 24
# generation 398 Max fitness: 25
# generation 399 Max fitness: 26
# generation 400 Max fitness: 25
# generation 401 Max fitness: 25
# generation 402 Max fitness: 25
# generation 403 Max fitness: 25
# generation 404 Max fitness: 24
# generation 405 Max fitness: 25
# generation 406 Max fitness: 26
# generation 407 Max fitness: 25
# generation 408 Max fitness: 25
# generation 409 Max fitness: 26
# generation 410 Max fitness: 24
# generation 411 Max fitness: 25
# generation 412 Max fitness: 26
# generation 413 Max fitness: 24
# generation 414 Max fitness: 25
# generation 415 Max fitness: 26
# generation 416 Max fitness: 24
# generation 417 Max fitness: 24
# generation 418 Max fitness: 25
# generation 419 Max fitness: 25
# generation 420 Max fitness: 26
# generation 421 Max fitness: 25
# generation 422 Max fitness: 24
# generation 423 Max fitness: 26
# generation 424 Max fitness: 24
# generation 425 Max fitness: 24
# generation 426 Max fitness: 25
# generation 427 Max fitness: 24
# generation 428 Max fitness: 26
# generation 429 Max fitness: 24
# generation 430 Max fitness: 24
# generation 431 Max fitness: 24
# generation 432 Max fitness: 25
# generation 433 Max fitness: 24
# generation 434 Max fitness: 26
# generation 435 Max fitness: 25
# generation 436 Max fitness: 24
# generation 437 Max fitness: 24
# generation 438 Max fitness: 25
# generation 439 Max fitness: 25
# generation 440 Max fitness: 24
# generation 441 Max fitness: 24
# generation 442 Max fitness: 25
# generation 443 Max fitness: 25
# generation 444 Max fitness: 25
# generation 445 Max fitness: 25
# generation 446 Max fitness: 25
# generation 447 Max fitness: 25
# generation 448 Max fitness: 24
# generation 449 Max fitness: 24
# generation 450 Max fitness: 26
# generation 451 Max fitness: 25
# generation 452 Max fitness: 24
# generation 453 Max fitness: 25
# generation 454 Max fitness: 24
# generation 455 Max fitness: 25
# generation 456 Max fitness: 25
# generation 457 Max fitness: 25
# generation 458 Max fitness: 24
# generation 459 Max fitness: 24
# generation 460 Max fitness: 24
# generation 461 Max fitness: 24
# generation 462 Max fitness: 25
# generation 463 Max fitness: 25
# generation 464 Max fitness: 25
# generation 465 Max fitness: 25
# generation 466 Max fitness: 25
# generation 467 Max fitness: 26
# generation 468 Max fitness: 25
# generation 469 Max fitness: 26
# generation 470 Max fitness: 24
# generation 471 Max fitness: 25
# generation 472 Max fitness: 25
# generation 473 Max fitness: 24
# generation 474 Max fitness: 24
# generation 475 Max fitness: 25
# generation 476 Max fitness: 26
# generation 477 Max fitness: 26
# generation 478 Max fitness: 25
# generation 479 Max fitness: 24
# generation 480 Max fitness: 24
# generation 481 Max fitness: 26
# generation 482 Max fitness: 25
# generation 483 Max fitness: 25
# generation 484 Max fitness: 24
# generation 485 Max fitness: 24
# generation 486 Max fitness: 26
# generation 487 Max fitness: 25
# generation 488 Max fitness: 25
# generation 489 Max fitness: 26
# generation 490 Max fitness: 24
# generation 491 Max fitness: 25
# generation 492 Max fitness: 26
# generation 493 Max fitness: 26
# generation 494 Max fitness: 24
# generation 495 Max fitness: 25
# generation 496 Max fitness: 25
# generation 497 Max fitness: 25
# generation 498 Max fitness: 25
# generation 499 Max fitness: 24
# generation 500 Max fitness: 25
# generation 501 Max fitness: 25
# generation 502 Max fitness: 24
# generation 503 Max fitness: 24
# generation 504 Max fitness: 25
# generation 505 Max fitness: 25
# generation 506 Max fitness: 25
# generation 507 Max fitness: 24
# generation 508 Max fitness: 24
# generation 509 Max fitness: 25
# generation 510 Max fitness: 24
# generation 511 Max fitness: 25
# generation 512 Max fitness: 25
# generation 513 Max fitness: 24
# generation 514 Max fitness: 24
# generation 515 Max fitness: 25
# generation 516 Max fitness: 25
# generation 517 Max fitness: 24
# generation 518 Max fitness: 25
# generation 519 Max fitness: 26
# generation 520 Max fitness: 25
# generation 521 Max fitness: 24
# generation 522 Max fitness: 23
# generation 523 Max fitness: 23
# generation 524 Max fitness: 24
# generation 525 Max fitness: 24
# generation 526 Max fitness: 24
# generation 527 Max fitness: 25
# generation 528 Max fitness: 25
# generation 529 Max fitness: 23
# generation 530 Max fitness: 25
# generation 531 Max fitness: 25
# generation 532 Max fitness: 25
# generation 533 Max fitness: 27
# generation 534 Max fitness: 24
# generation 535 Max fitness: 25
# generation 536 Max fitness: 26
# generation 537 Max fitness: 23
# generation 538 Max fitness: 25
# generation 539 Max fitness: 25
# generation 540 Max fitness: 24
# generation 541 Max fitness: 24
# generation 542 Max fitness: 26
# generation 543 Max fitness: 25
# generation 544 Max fitness: 24
# generation 545 Max fitness: 24
# generation 546 Max fitness: 24
# generation 547 Max fitness: 25
# generation 548 Max fitness: 25
# generation 549 Max fitness: 26
# generation 550 Max fitness: 26
# generation 551 Max fitness: 25
# generation 552 Max fitness: 24
# generation 553 Max fitness: 27
# generation 554 Max fitness: 27
# generation 555 Max fitness: 27
# generation 556 Max fitness: 25
# generation 557 Max fitness: 24
# generation 558 Max fitness: 25
# generation 559 Max fitness: 24
# generation 560 Max fitness: 23
# generation 561 Max fitness: 24
# generation 562 Max fitness: 25
# generation 563 Max fitness: 25
# generation 564 Max fitness: 25
# generation 565 Max fitness: 24
# generation 566 Max fitness: 25
# generation 567 Max fitness: 25
# generation 568 Max fitness: 25
# generation 569 Max fitness: 24
# generation 570 Max fitness: 25
# generation 571 Max fitness: 23
# generation 572 Max fitness: 24
# generation 573 Max fitness: 24
# generation 574 Max fitness: 24
# generation 575 Max fitness: 25
# generation 576 Max fitness: 25
# generation 577 Max fitness: 24
# generation 578 Max fitness: 25
# generation 579 Max fitness: 26
# generation 580 Max fitness: 25
# generation 581 Max fitness: 24
# generation 582 Max fitness: 25
# generation 583 Max fitness: 25
# generation 584 Max fitness: 25
# generation 585 Max fitness: 25
# generation 586 Max fitness: 26
# generation 587 Max fitness: 26
# generation 588 Max fitness: 25
# generation 589 Max fitness: 26
# generation 590 Max fitness: 25
# generation 591 Max fitness: 25
# generation 592 Max fitness: 25
# generation 593 Max fitness: 24
# generation 594 Max fitness: 24
# generation 595 Max fitness: 25
# generation 596 Max fitness: 24
# generation 597 Max fitness: 26
# generation 598 Max fitness: 25
# generation 599 Max fitness: 25
# generation 600 Max fitness: 24
# generation 601 Max fitness: 24
# generation 602 Max fitness: 25
# generation 603 Max fitness: 25
# generation 604 Max fitness: 26
# generation 605 Max fitness: 26
# generation 606 Max fitness: 24
# generation 607 Max fitness: 24
# generation 608 Max fitness: 23
# generation 609 Max fitness: 25
# generation 610 Max fitness: 25
# generation 611 Max fitness: 26
# generation 612 Max fitness: 25
# generation 613 Max fitness: 24
# generation 614 Max fitness: 25
# generation 615 Max fitness: 25
# generation 616 Max fitness: 26
# generation 617 Max fitness: 24
# generation 618 Max fitness: 25
# generation 619 Max fitness: 25
# generation 620 Max fitness: 25
# generation 621 Max fitness: 25
# generation 622 Max fitness: 26
# generation 623 Max fitness: 25
# generation 624 Max fitness: 25
# generation 625 Max fitness: 25
# generation 626 Max fitness: 24
# generation 627 Max fitness: 24
# generation 628 Max fitness: 24
# generation 629 Max fitness: 25
# generation 630 Max fitness: 26
# generation 631 Max fitness: 25
# generation 632 Max fitness: 25
# generation 633 Max fitness: 25
# generation 634 Max fitness: 24
# generation 635 Max fitness: 26
# generation 636 Max fitness: 25
# generation 637 Max fitness: 25
# generation 638 Max fitness: 25
# generation 639 Max fitness: 23
# generation 640 Max fitness: 25
# generation 641 Max fitness: 26
# generation 642 Max fitness: 23
# generation 643 Max fitness: 24
# generation 644 Max fitness: 24
# generation 645 Max fitness: 25
# generation 646 Max fitness: 25
# generation 647 Max fitness: 25
# generation 648 Max fitness: 24
# generation 649 Max fitness: 25
# generation 650 Max fitness: 24
# generation 651 Max fitness: 25
# generation 652 Max fitness: 26
# generation 653 Max fitness: 25
# generation 654 Max fitness: 25
# generation 655 Max fitness: 25
# generation 656 Max fitness: 26
# generation 657 Max fitness: 24
# generation 658 Max fitness: 25
# generation 659 Max fitness: 24
# generation 660 Max fitness: 25
# generation 661 Max fitness: 23
# generation 662 Max fitness: 24
# generation 663 Max fitness: 26
# generation 664 Max fitness: 25
# generation 665 Max fitness: 25
# generation 666 Max fitness: 27
# generation 667 Max fitness: 25
# generation 668 Max fitness: 24
# generation 669 Max fitness: 24
# generation 670 Max fitness: 25
# generation 671 Max fitness: 24
# generation 672 Max fitness: 25
# generation 673 Max fitness: 24
# generation 674 Max fitness: 25
# generation 675 Max fitness: 26
# generation 676 Max fitness: 26
# generation 677 Max fitness: 24
# generation 678 Max fitness: 25
# generation 679 Max fitness: 25
# generation 680 Max fitness: 25
# generation 681 Max fitness: 26
# generation 682 Max fitness: 24
# generation 683 Max fitness: 25
# generation 684 Max fitness: 25
# generation 685 Max fitness: 27
# generation 686 Max fitness: 24
# generation 687 Max fitness: 25
# generation 688 Max fitness: 25
# generation 689 Max fitness: 26
# generation 690 Max fitness: 24
# generation 691 Max fitness: 24
# generation 692 Max fitness: 23
# generation 693 Max fitness: 26
# generation 694 Max fitness: 25
# generation 695 Max fitness: 25
# generation 696 Max fitness: 26
# generation 697 Max fitness: 24
# generation 698 Max fitness: 25
# generation 699 Max fitness: 25
# generation 700 Max fitness: 26
# generation 701 Max fitness: 26
# generation 702 Max fitness: 26
# generation 703 Max fitness: 26
# generation 704 Max fitness: 26
# generation 705 Max fitness: 25
# generation 706 Max fitness: 25
# generation 707 Max fitness: 25
# generation 708 Max fitness: 26
# generation 709 Max fitness: 26
# generation 710 Max fitness: 25
# generation 711 Max fitness: 25
# generation 712 Max fitness: 24
# generation 713 Max fitness: 25
# generation 714 Max fitness: 24
# generation 715 Max fitness: 26
# generation 716 Max fitness: 24
# generation 717 Max fitness: 24
# generation 718 Max fitness: 25
# generation 719 Max fitness: 25
# generation 720 Max fitness: 25
# generation 721 Max fitness: 25
# generation 722 Max fitness: 24
# generation 723 Max fitness: 24
# generation 724 Max fitness: 24
# generation 725 Max fitness: 24
# generation 726 Max fitness: 25
# generation 727 Max fitness: 25
# generation 728 Max fitness: 25
# generation 729 Max fitness: 24
# generation 730 Max fitness: 24
# generation 731 Max fitness: 25
# generation 732 Max fitness: 25
# generation 733 Max fitness: 26
# generation 734 Max fitness: 25
# generation 735 Max fitness: 26
# generation 736 Max fitness: 25
# generation 737 Max fitness: 25
# generation 738 Max fitness: 25
# generation 739 Max fitness: 24
# generation 740 Max fitness: 24
# generation 741 Max fitness: 25
# generation 742 Max fitness: 25
# generation 743 Max fitness: 25
# generation 744 Max fitness: 24
# generation 745 Max fitness: 25
# generation 746 Max fitness: 25
# generation 747 Max fitness: 26
# generation 748 Max fitness: 25
# generation 749 Max fitness: 24
# generation 750 Max fitness: 26
# generation 751 Max fitness: 26
# generation 752 Max fitness: 24
# generation 753 Max fitness: 25
# generation 754 Max fitness: 27
# generation 755 Max fitness: 25
# generation 756 Max fitness: 25
# generation 757 Max fitness: 24
# generation 758 Max fitness: 26
# generation 759 Max fitness: 26
# generation 760 Max fitness: 25
# generation 761 Max fitness: 26
# generation 762 Max fitness: 24
# generation 763 Max fitness: 25
# generation 764 Max fitness: 26
# generation 765 Max fitness: 23
# generation 766 Max fitness: 24
# generation 767 Max fitness: 26
# generation 768 Max fitness: 24
# generation 769 Max fitness: 24
# generation 770 Max fitness: 26
# generation 771 Max fitness: 26
# generation 772 Max fitness: 25
# generation 773 Max fitness: 25
# generation 774 Max fitness: 24
# generation 775 Max fitness: 26
# generation 776 Max fitness: 25
# generation 777 Max fitness: 25
# generation 778 Max fitness: 25
# generation 779 Max fitness: 24
# generation 780 Max fitness: 25
# generation 781 Max fitness: 24
# generation 782 Max fitness: 25
# generation 783 Max fitness: 25
# generation 784 Max fitness: 24
# generation 785 Max fitness: 24
# generation 786 Max fitness: 24
# generation 787 Max fitness: 25
# generation 788 Max fitness: 25
# generation 789 Max fitness: 27
# generation 790 Max fitness: 27
# generation 791 Max fitness: 24
# generation 792 Max fitness: 24
# generation 793 Max fitness: 24
# generation 794 Max fitness: 25
# generation 795 Max fitness: 26
# generation 796 Max fitness: 25
# generation 797 Max fitness: 25
# generation 798 Max fitness: 24
# generation 799 Max fitness: 25
# generation 800 Max fitness: 25
# generation 801 Max fitness: 24
# generation 802 Max fitness: 24
# generation 803 Max fitness: 25
# generation 804 Max fitness: 24
# generation 805 Max fitness: 25
# generation 806 Max fitness: 25
# generation 807 Max fitness: 26
# generation 808 Max fitness: 25
# generation 809 Max fitness: 26
# generation 810 Max fitness: 24
# generation 811 Max fitness: 25
# generation 812 Max fitness: 24
# generation 813 Max fitness: 25
# generation 814 Max fitness: 24
# generation 815 Max fitness: 24
# generation 816 Max fitness: 24
# generation 817 Max fitness: 24
# generation 818 Max fitness: 25
# generation 819 Max fitness: 25
# generation 820 Max fitness: 24
# generation 821 Max fitness: 26
# generation 822 Max fitness: 24
# generation 823 Max fitness: 25
# generation 824 Max fitness: 24
# generation 825 Max fitness: 25
# generation 826 Max fitness: 24
# generation 827 Max fitness: 26
# generation 828 Max fitness: 25
# generation 829 Max fitness: 25
# generation 830 Max fitness: 26
# generation 831 Max fitness: 24
# generation 832 Max fitness: 25
# generation 833 Max fitness: 25
# generation 834 Max fitness: 25
# generation 835 Max fitness: 25
# generation 836 Max fitness: 24
# generation 837 Max fitness: 26
# generation 838 Max fitness: 25
# generation 839 Max fitness: 24
# generation 840 Max fitness: 24
# generation 841 Max fitness: 25
# generation 842 Max fitness: 25
# generation 843 Max fitness: 26
# generation 844 Max fitness: 26
# generation 845 Max fitness: 25
# generation 846 Max fitness: 26
# generation 847 Max fitness: 25
# generation 848 Max fitness: 25
# generation 849 Max fitness: 25
# generation 850 Max fitness: 25
# generation 851 Max fitness: 25
# generation 852 Max fitness: 26
# generation 853 Max fitness: 25
# generation 854 Max fitness: 26
# generation 855 Max fitness: 25
# generation 856 Max fitness: 25
# generation 857 Max fitness: 24
# generation 858 Max fitness: 24
# generation 859 Max fitness: 24
# generation 860 Max fitness: 24
# generation 861 Max fitness: 26
# generation 862 Max fitness: 25
# generation 863 Max fitness: 25
# generation 864 Max fitness: 25
# generation 865 Max fitness: 26
# generation 866 Max fitness: 24
# generation 867 Max fitness: 23
# generation 868 Max fitness: 25
# generation 869 Max fitness: 27
# generation 870 Max fitness: 25
# generation 871 Max fitness: 25
# generation 872 Max fitness: 26
# generation 873 Max fitness: 26
# generation 874 Max fitness: 25
# generation 875 Max fitness: 24
# generation 876 Max fitness: 26
# generation 877 Max fitness: 25
# generation 878 Max fitness: 25
# generation 879 Max fitness: 25
# generation 880 Max fitness: 24
# generation 881 Max fitness: 24
# generation 882 Max fitness: 24
# generation 883 Max fitness: 25
# generation 884 Max fitness: 25
# generation 885 Max fitness: 25
# generation 886 Max fitness: 25
# generation 887 Max fitness: 23
# generation 888 Max fitness: 26
# generation 889 Max fitness: 25
# generation 890 Max fitness: 25
# generation 891 Max fitness: 25
# generation 892 Max fitness: 24
# generation 893 Max fitness: 25
# generation 894 Max fitness: 26
# generation 895 Max fitness: 25
# generation 896 Max fitness: 25
# generation 897 Max fitness: 25
# generation 898 Max fitness: 25
# generation 899 Max fitness: 25
# generation 900 Max fitness: 26
# generation 901 Max fitness: 24
# generation 902 Max fitness: 25
# generation 903 Max fitness: 25
# generation 904 Max fitness: 24
# generation 905 Max fitness: 24
# generation 906 Max fitness: 26
# generation 907 Max fitness: 24
# generation 908 Max fitness: 25
# generation 909 Max fitness: 25
# generation 910 Max fitness: 25
# generation 911 Max fitness: 25
# generation 912 Max fitness: 24
# generation 913 Max fitness: 25
# generation 914 Max fitness: 26
# generation 915 Max fitness: 26
# generation 916 Max fitness: 25
# generation 917 Max fitness: 25
# generation 918 Max fitness: 24
# generation 919 Max fitness: 25
# generation 920 Max fitness: 25
# generation 921 Max fitness: 25
# generation 922 Max fitness: 25
# generation 923 Max fitness: 24
# generation 924 Max fitness: 24
# generation 925 Max fitness: 24
# generation 926 Max fitness: 24
# generation 927 Max fitness: 24
# generation 928 Max fitness: 25
# generation 929 Max fitness: 25
# generation 930 Max fitness: 25
# generation 931 Max fitness: 25
# generation 932 Max fitness: 26
# generation 933 Max fitness: 24
# generation 934 Max fitness: 24
# generation 935 Max fitness: 25
# generation 936 Max fitness: 24
# generation 937 Max fitness: 25
# generation 938 Max fitness: 24
# generation 939 Max fitness: 25
# generation 940 Max fitness: 23
# generation 941 Max fitness: 24
# generation 942 Max fitness: 25
# generation 943 Max fitness: 25
# generation 944 Max fitness: 24
# generation 945 Max fitness: 25
# generation 946 Max fitness: 23
# generation 947 Max fitness: 25
# generation 948 Max fitness: 24
# generation 949 Max fitness: 25
# generation 950 Max fitness: 26
# generation 951 Max fitness: 25
# generation 952 Max fitness: 25
# generation 953 Max fitness: 26
# generation 954 Max fitness: 25
# generation 955 Max fitness: 25
# generation 956 Max fitness: 25
# generation 957 Max fitness: 25
# generation 958 Max fitness: 24
# generation 959 Max fitness: 26
# generation 960 Max fitness: 26
# generation 961 Max fitness: 24
# generation 962 Max fitness: 25
# generation 963 Max fitness: 25
# generation 964 Max fitness: 26
# generation 965 Max fitness: 25
# generation 966 Max fitness: 24
# generation 967 Max fitness: 24
# generation 968 Max fitness: 26
# generation 969 Max fitness: 26
# generation 970 Max fitness: 25
# generation 971 Max fitness: 25
# generation 972 Max fitness: 24
# generation 973 Max fitness: 24
# generation 974 Max fitness: 25
# generation 975 Max fitness: 25
# generation 976 Max fitness: 23
# generation 977 Max fitness: 25
# generation 978 Max fitness: 24
# generation 979 Max fitness: 24
# generation 980 Max fitness: 25
# generation 981 Max fitness: 24
# generation 982 Max fitness: 25
# generation 983 Max fitness: 24
# generation 984 Max fitness: 22
# generation 985 Max fitness: 24
# generation 986 Max fitness: 24
# generation 987 Max fitness: 24
# generation 988 Max fitness: 24
# generation 989 Max fitness: 25
# generation 990 Max fitness: 26
# generation 991 Max fitness: 25
# generation 992 Max fitness: 25
# generation 993 Max fitness: 25
# generation 994 Max fitness: 25
# generation 995 Max fitness: 24
# generation 996 Max fitness: 25
# generation 997 Max fitness: 26
# generation 998 Max fitness: 25
# generation 999 Max fitness: 24
# generation 1000 Max fitness: 24
# generation 1001 Max fitness: 26
# generation 1002 Max fitness: 24
# generation 1003 Max fitness: 26
# generation 1004 Max fitness: 24
# generation 1005 Max fitness: 25
# generation 1006 Max fitness: 25
# generation 1007 Max fitness: 24
# generation 1008 Max fitness: 25
# generation 1009 Max fitness: 25
# generation 1010 Max fitness: 25
# generation 1011 Max fitness: 25
# generation 1012 Max fitness: 24
# generation 1013 Max fitness: 25
# generation 1014 Max fitness: 24
# generation 1015 Max fitness: 24
# generation 1016 Max fitness: 27
# generation 1017 Max fitness: 26
# generation 1018 Max fitness: 27
# generation 1019 Max fitness: 25
# generation 1020 Max fitness: 25
# generation 1021 Max fitness: 25
# generation 1022 Max fitness: 24
# generation 1023 Max fitness: 25
# generation 1024 Max fitness: 24
# generation 1025 Max fitness: 24
# generation 1026 Max fitness: 24
# generation 1027 Max fitness: 25
# generation 1028 Max fitness: 25
# generation 1029 Max fitness: 25
# generation 1030 Max fitness: 25
# generation 1031 Max fitness: 25
# generation 1032 Max fitness: 26
# generation 1033 Max fitness: 25
# generation 1034 Max fitness: 26
# generation 1035 Max fitness: 25
# generation 1036 Max fitness: 25
# generation 1037 Max fitness: 24
# generation 1038 Max fitness: 25
# generation 1039 Max fitness: 25
# generation 1040 Max fitness: 24
# generation 1041 Max fitness: 25
# generation 1042 Max fitness: 26
# generation 1043 Max fitness: 25
# generation 1044 Max fitness: 24
# generation 1045 Max fitness: 26
# generation 1046 Max fitness: 25
# generation 1047 Max fitness: 25
# generation 1048 Max fitness: 25
# generation 1049 Max fitness: 25
# generation 1050 Max fitness: 25
# generation 1051 Max fitness: 24
# generation 1052 Max fitness: 24
# generation 1053 Max fitness: 24
# generation 1054 Max fitness: 26
# generation 1055 Max fitness: 25
# generation 1056 Max fitness: 25
# generation 1057 Max fitness: 26
# generation 1058 Max fitness: 25
# generation 1059 Max fitness: 25
# generation 1060 Max fitness: 25
# generation 1061 Max fitness: 26
# generation 1062 Max fitness: 26
# generation 1063 Max fitness: 26
# generation 1064 Max fitness: 26
# generation 1065 Max fitness: 26
# generation 1066 Max fitness: 24
# generation 1067 Max fitness: 25
# generation 1068 Max fitness: 25
# generation 1069 Max fitness: 27
# generation 1070 Max fitness: 25
# generation 1071 Max fitness: 25
# generation 1072 Max fitness: 24
# generation 1073 Max fitness: 24
# generation 1074 Max fitness: 24
# generation 1075 Max fitness: 25
# generation 1076 Max fitness: 25
# generation 1077 Max fitness: 26
# generation 1078 Max fitness: 25
# generation 1079 Max fitness: 25
# generation 1080 Max fitness: 26
# generation 1081 Max fitness: 25
# generation 1082 Max fitness: 24
# generation 1083 Max fitness: 24
# generation 1084 Max fitness: 26
# generation 1085 Max fitness: 25
# generation 1086 Max fitness: 26
# generation 1087 Max fitness: 25
# generation 1088 Max fitness: 24
# generation 1089 Max fitness: 26
# generation 1090 Max fitness: 25
# generation 1091 Max fitness: 25
# generation 1092 Max fitness: 24
# generation 1093 Max fitness: 24
# generation 1094 Max fitness: 25
# generation 1095 Max fitness: 25
# generation 1096 Max fitness: 24
# generation 1097 Max fitness: 25
# generation 1098 Max fitness: 25
# generation 1099 Max fitness: 26
# generation 1100 Max fitness: 25
# generation 1101 Max fitness: 25
# generation 1102 Max fitness: 25
# generation 1103 Max fitness: 24
# generation 1104 Max fitness: 25
# generation 1105 Max fitness: 25
# generation 1106 Max fitness: 24
# generation 1107 Max fitness: 25
# generation 1108 Max fitness: 24
# generation 1109 Max fitness: 24
# generation 1110 Max fitness: 23
# generation 1111 Max fitness: 24
# generation 1112 Max fitness: 25
# generation 1113 Max fitness: 24
# generation 1114 Max fitness: 26
# generation 1115 Max fitness: 24
# generation 1116 Max fitness: 25
# generation 1117 Max fitness: 25
# generation 1118 Max fitness: 25
# generation 1119 Max fitness: 26
# generation 1120 Max fitness: 25
# generation 1121 Max fitness: 27
# generation 1122 Max fitness: 25
# generation 1123 Max fitness: 25
# generation 1124 Max fitness: 24
# generation 1125 Max fitness: 26
# generation 1126 Max fitness: 24
# generation 1127 Max fitness: 25
# generation 1128 Max fitness: 24
# generation 1129 Max fitness: 25
# generation 1130 Max fitness: 26
# generation 1131 Max fitness: 24
# generation 1132 Max fitness: 25
# generation 1133 Max fitness: 26
# generation 1134 Max fitness: 26
# generation 1135 Max fitness: 25
# generation 1136 Max fitness: 25
# generation 1137 Max fitness: 24
# generation 1138 Max fitness: 25
# generation 1139 Max fitness: 25
# generation 1140 Max fitness: 25
# generation 1141 Max fitness: 25
# generation 1142 Max fitness: 24
# generation 1143 Max fitness: 25
# generation 1144 Max fitness: 24
# generation 1145 Max fitness: 24
# generation 1146 Max fitness: 26
# generation 1147 Max fitness: 25
# generation 1148 Max fitness: 24
# generation 1149 Max fitness: 25
# generation 1150 Max fitness: 26
# generation 1151 Max fitness: 25
# generation 1152 Max fitness: 26
# generation 1153 Max fitness: 26
# generation 1154 Max fitness: 24
# generation 1155 Max fitness: 24
# generation 1156 Max fitness: 24
# generation 1157 Max fitness: 25
# generation 1158 Max fitness: 25
# generation 1159 Max fitness: 25
# generation 1160 Max fitness: 25
# generation 1161 Max fitness: 24
# generation 1162 Max fitness: 25
# generation 1163 Max fitness: 24
# generation 1164 Max fitness: 25
# generation 1165 Max fitness: 25
# generation 1166 Max fitness: 25
# generation 1167 Max fitness: 25
# generation 1168 Max fitness: 26
# generation 1169 Max fitness: 26
# generation 1170 Max fitness: 25
# generation 1171 Max fitness: 25
# generation 1172 Max fitness: 25
# generation 1173 Max fitness: 24
# generation 1174 Max fitness: 26
# generation 1175 Max fitness: 25
# generation 1176 Max fitness: 25
# generation 1177 Max fitness: 24
# generation 1178 Max fitness: 24
# generation 1179 Max fitness: 25
# generation 1180 Max fitness: 26
# generation 1181 Max fitness: 24
# generation 1182 Max fitness: 25
# generation 1183 Max fitness: 24
# generation 1184 Max fitness: 24
# generation 1185 Max fitness: 26
# generation 1186 Max fitness: 26
# generation 1187 Max fitness: 23
# generation 1188 Max fitness: 25
# generation 1189 Max fitness: 24
# generation 1190 Max fitness: 25
# generation 1191 Max fitness: 25
# generation 1192 Max fitness: 25
# generation 1193 Max fitness: 24
# generation 1194 Max fitness: 25
# generation 1195 Max fitness: 25
# generation 1196 Max fitness: 26
# generation 1197 Max fitness: 25
# generation 1198 Max fitness: 25
# generation 1199 Max fitness: 26
# generation 1200 Max fitness: 25
# generation 1201 Max fitness: 25
# generation 1202 Max fitness: 24
# generation 1203 Max fitness: 24
# generation 1204 Max fitness: 25
# generation 1205 Max fitness: 24
# generation 1206 Max fitness: 26
# generation 1207 Max fitness: 25
# generation 1208 Max fitness: 25
# generation 1209 Max fitness: 26
# generation 1210 Max fitness: 24
# generation 1211 Max fitness: 25
# generation 1212 Max fitness: 25
# generation 1213 Max fitness: 25
# generation 1214 Max fitness: 25
# generation 1215 Max fitness: 26
# generation 1216 Max fitness: 25
# generation 1217 Max fitness: 24
# generation 1218 Max fitness: 27
# generation 1219 Max fitness: 24
# generation 1220 Max fitness: 25
# generation 1221 Max fitness: 24
# generation 1222 Max fitness: 25
# generation 1223 Max fitness: 26
# generation 1224 Max fitness: 24
# generation 1225 Max fitness: 24
# generation 1226 Max fitness: 25
# generation 1227 Max fitness: 24
# generation 1228 Max fitness: 25
# generation 1229 Max fitness: 26
# generation 1230 Max fitness: 24
# generation 1231 Max fitness: 25
# generation 1232 Max fitness: 25
# generation 1233 Max fitness: 25
# generation 1234 Max fitness: 25
# generation 1235 Max fitness: 24
# generation 1236 Max fitness: 24
# generation 1237 Max fitness: 26
# generation 1238 Max fitness: 26
# generation 1239 Max fitness: 25
# generation 1240 Max fitness: 25
# generation 1241 Max fitness: 24
# generation 1242 Max fitness: 26
# generation 1243 Max fitness: 24
# generation 1244 Max fitness: 24
# generation 1245 Max fitness: 25
# generation 1246 Max fitness: 24
# generation 1247 Max fitness: 24
# generation 1248 Max fitness: 24
# generation 1249 Max fitness: 24
# generation 1250 Max fitness: 24
# generation 1251 Max fitness: 26
# generation 1252 Max fitness: 26
# generation 1253 Max fitness: 25
# generation 1254 Max fitness: 25
# generation 1255 Max fitness: 26
# generation 1256 Max fitness: 26
# generation 1257 Max fitness: 24
# generation 1258 Max fitness: 25
# generation 1259 Max fitness: 25
# generation 1260 Max fitness: 26
# generation 1261 Max fitness: 25
# generation 1262 Max fitness: 26
# generation 1263 Max fitness: 25
# generation 1264 Max fitness: 25
# generation 1265 Max fitness: 25
# generation 1266 Max fitness: 25
# generation 1267 Max fitness: 25
# generation 1268 Max fitness: 24
# generation 1269 Max fitness: 24
# generation 1270 Max fitness: 25
# generation 1271 Max fitness: 25
# generation 1272 Max fitness: 26
# generation 1273 Max fitness: 25
# generation 1274 Max fitness: 24
# generation 1275 Max fitness: 25
# generation 1276 Max fitness: 25
# generation 1277 Max fitness: 25
# generation 1278 Max fitness: 25
# generation 1279 Max fitness: 25
# generation 1280 Max fitness: 26
# generation 1281 Max fitness: 24
# generation 1282 Max fitness: 25
# generation 1283 Max fitness: 25
# generation 1284 Max fitness: 25
# generation 1285 Max fitness: 26
# generation 1286 Max fitness: 25
# generation 1287 Max fitness: 25
# generation 1288 Max fitness: 25
# generation 1289 Max fitness: 23
# generation 1290 Max fitness: 25
# generation 1291 Max fitness: 25
# generation 1292 Max fitness: 24
# generation 1293 Max fitness: 24
# generation 1294 Max fitness: 25
# generation 1295 Max fitness: 25
# generation 1296 Max fitness: 24
# generation 1297 Max fitness: 23
# generation 1298 Max fitness: 25
# generation 1299 Max fitness: 24
# generation 1300 Max fitness: 25
# generation 1301 Max fitness: 24
# generation 1302 Max fitness: 25
# generation 1303 Max fitness: 26
# generation 1304 Max fitness: 26
# generation 1305 Max fitness: 25
# generation 1306 Max fitness: 26
# generation 1307 Max fitness: 24
# generation 1308 Max fitness: 25
# generation 1309 Max fitness: 25
# generation 1310 Max fitness: 26
# generation 1311 Max fitness: 26
# generation 1312 Max fitness: 25
# generation 1313 Max fitness: 25
# generation 1314 Max fitness: 25
# generation 1315 Max fitness: 25
# generation 1316 Max fitness: 26
# generation 1317 Max fitness: 26
# generation 1318 Max fitness: 25
# generation 1319 Max fitness: 24
# generation 1320 Max fitness: 25
# generation 1321 Max fitness: 25
# generation 1322 Max fitness: 26
# generation 1323 Max fitness: 25
# generation 1324 Max fitness: 24
# generation 1325 Max fitness: 24
# generation 1326 Max fitness: 26
# generation 1327 Max fitness: 25
# generation 1328 Max fitness: 23
# generation 1329 Max fitness: 24
# generation 1330 Max fitness: 24
# generation 1331 Max fitness: 24
# generation 1332 Max fitness: 25
# generation 1333 Max fitness: 24
# generation 1334 Max fitness: 24
# generation 1335 Max fitness: 26
# generation 1336 Max fitness: 25
# generation 1337 Max fitness: 25
# generation 1338 Max fitness: 24
# generation 1339 Max fitness: 26
# generation 1340 Max fitness: 25
# generation 1341 Max fitness: 25
# generation 1342 Max fitness: 25
# generation 1343 Max fitness: 25
# generation 1344 Max fitness: 25
# generation 1345 Max fitness: 24
# generation 1346 Max fitness: 24
# generation 1347 Max fitness: 24
# generation 1348 Max fitness: 25
# generation 1349 Max fitness: 24
# generation 1350 Max fitness: 25
# generation 1351 Max fitness: 25
# generation 1352 Max fitness: 25
# generation 1353 Max fitness: 23
# generation 1354 Max fitness: 24
# generation 1355 Max fitness: 24
# generation 1356 Max fitness: 25
# generation 1357 Max fitness: 26
# generation 1358 Max fitness: 25
# generation 1359 Max fitness: 25
# generation 1360 Max fitness: 26
# generation 1361 Max fitness: 25
# generation 1362 Max fitness: 25
# generation 1363 Max fitness: 25
# generation 1364 Max fitness: 26
# generation 1365 Max fitness: 24
# generation 1366 Max fitness: 26
# generation 1367 Max fitness: 25
# generation 1368 Max fitness: 24
# generation 1369 Max fitness: 25
# generation 1370 Max fitness: 26
# generation 1371 Max fitness: 25
# generation 1372 Max fitness: 25
# generation 1373 Max fitness: 26
# generation 1374 Max fitness: 25
# generation 1375 Max fitness: 26
# generation 1376 Max fitness: 24
# generation 1377 Max fitness: 25
# generation 1378 Max fitness: 25
# generation 1379 Max fitness: 26
# generation 1380 Max fitness: 26
# generation 1381 Max fitness: 25
# generation 1382 Max fitness: 24
# generation 1383 Max fitness: 25
# generation 1384 Max fitness: 26
# generation 1385 Max fitness: 24
# generation 1386 Max fitness: 24
# generation 1387 Max fitness: 26
# generation 1388 Max fitness: 25
# generation 1389 Max fitness: 24
# generation 1390 Max fitness: 24
# generation 1391 Max fitness: 26
# generation 1392 Max fitness: 25
# generation 1393 Max fitness: 25
# generation 1394 Max fitness: 24
# generation 1395 Max fitness: 24
# generation 1396 Max fitness: 25
# generation 1397 Max fitness: 25
# generation 1398 Max fitness: 24
# generation 1399 Max fitness: 24
# generation 1400 Max fitness: 25
# generation 1401 Max fitness: 25
# generation 1402 Max fitness: 24
# generation 1403 Max fitness: 25
# generation 1404 Max fitness: 24
# generation 1405 Max fitness: 24
# generation 1406 Max fitness: 26
# generation 1407 Max fitness: 25
# generation 1408 Max fitness: 25
# generation 1409 Max fitness: 24
# generation 1410 Max fitness: 25
# generation 1411 Max fitness: 26
# generation 1412 Max fitness: 25
# generation 1413 Max fitness: 25
# generation 1414 Max fitness: 25
# generation 1415 Max fitness: 24
# generation 1416 Max fitness: 24
# generation 1417 Max fitness: 24
# generation 1418 Max fitness: 24
# generation 1419 Max fitness: 25
# generation 1420 Max fitness: 24
# generation 1421 Max fitness: 24
# generation 1422 Max fitness: 24
# generation 1423 Max fitness: 25
# generation 1424 Max fitness: 26
# generation 1425 Max fitness: 26
# generation 1426 Max fitness: 25
# generation 1427 Max fitness: 25
# generation 1428 Max fitness: 26
# generation 1429 Max fitness: 27
# generation 1430 Max fitness: 25
# generation 1431 Max fitness: 25
# generation 1432 Max fitness: 26
# generation 1433 Max fitness: 24
# generation 1434 Max fitness: 25
# generation 1435 Max fitness: 26
# generation 1436 Max fitness: 25
# generation 1437 Max fitness: 25
# generation 1438 Max fitness: 25
# generation 1439 Max fitness: 25
# generation 1440 Max fitness: 24
# generation 1441 Max fitness: 24
# generation 1442 Max fitness: 25
# generation 1443 Max fitness: 23
# generation 1444 Max fitness: 25
# generation 1445 Max fitness: 24
# generation 1446 Max fitness: 26
# generation 1447 Max fitness: 24
# generation 1448 Max fitness: 25
# generation 1449 Max fitness: 24
# generation 1450 Max fitness: 24
# generation 1451 Max fitness: 25
# generation 1452 Max fitness: 25
# generation 1453 Max fitness: 25
# generation 1454 Max fitness: 25
# generation 1455 Max fitness: 25
# generation 1456 Max fitness: 24
# generation 1457 Max fitness: 24
# generation 1458 Max fitness: 25
# generation 1459 Max fitness: 26
# generation 1460 Max fitness: 25
# generation 1461 Max fitness: 25
# generation 1462 Max fitness: 25
# generation 1463 Max fitness: 25
# generation 1464 Max fitness: 25
# generation 1465 Max fitness: 23
# generation 1466 Max fitness: 24
# generation 1467 Max fitness: 25
# generation 1468 Max fitness: 24
# generation 1469 Max fitness: 25
# generation 1470 Max fitness: 25
# generation 1471 Max fitness: 24
# generation 1472 Max fitness: 25
# generation 1473 Max fitness: 25
# generation 1474 Max fitness: 25
# generation 1475 Max fitness: 26
# generation 1476 Max fitness: 25
# generation 1477 Max fitness: 25
# generation 1478 Max fitness: 25
# generation 1479 Max fitness: 25
# generation 1480 Max fitness: 25
# generation 1481 Max fitness: 24
# generation 1482 Max fitness: 23
# generation 1483 Max fitness: 25
# generation 1484 Max fitness: 25
# generation 1485 Max fitness: 24
# generation 1486 Max fitness: 26
# generation 1487 Max fitness: 25
# generation 1488 Max fitness: 25
# generation 1489 Max fitness: 25
# generation 1490 Max fitness: 24
# generation 1491 Max fitness: 24
# generation 1492 Max fitness: 23
# generation 1493 Max fitness: 25
# generation 1494 Max fitness: 25
# generation 1495 Max fitness: 26
# generation 1496 Max fitness: 26
# generation 1497 Max fitness: 25
# generation 1498 Max fitness: 25
# generation 1499 Max fitness: 24
# generation 1500 Max fitness: 25
# generation 1501 Max fitness: 25
# generation 1502 Max fitness: 25
# generation 1503 Max fitness: 25
# generation 1504 Max fitness: 26
# generation 1505 Max fitness: 25
# generation 1506 Max fitness: 26
# generation 1507 Max fitness: 26
# generation 1508 Max fitness: 25
# generation 1509 Max fitness: 24
# generation 1510 Max fitness: 26
# generation 1511 Max fitness: 24
# generation 1512 Max fitness: 23
# generation 1513 Max fitness: 24
# generation 1514 Max fitness: 25
# generation 1515 Max fitness: 25
# generation 1516 Max fitness: 25
# generation 1517 Max fitness: 24
# generation 1518 Max fitness: 24
# generation 1519 Max fitness: 25
# generation 1520 Max fitness: 26
# generation 1521 Max fitness: 27
# generation 1522 Max fitness: 24
# generation 1523 Max fitness: 24
# generation 1524 Max fitness: 25
# generation 1525 Max fitness: 24
# generation 1526 Max fitness: 24
# generation 1527 Max fitness: 24
# generation 1528 Max fitness: 25
# generation 1529 Max fitness: 25
# generation 1530 Max fitness: 25
# generation 1531 Max fitness: 26
# generation 1532 Max fitness: 26
# generation 1533 Max fitness: 26
# generation 1534 Max fitness: 25
# ...
# generation 2142 Max fitness: 26
# generation 2143 Max fitness: 25
# generation 2144 Max fitness: 26
# generation 2145 Max fitness: 25
# generation 2146 Max fitness: 24
# generation 2147 Max fitness: 25
# generation 2148 Max fitness: 24
# generation 2149 Max fitness: 24
# generation 2150 Max fitness: 24
# generation 2151 Max fitness: 24
# generation 2152 Max fitness: 25
# generation 2153 Max fitness: 26
# generation 2154 Max fitness: 25
# generation 2155 Max fitness: 25
# generation 2156 Max fitness: 25
# generation 2157 Max fitness: 25
# generation 2158 Max fitness: 24
# generation 2159 Max fitness: 24
# generation 2160 Max fitness: 25
# generation 2161 Max fitness: 25
# generation 2162 Max fitness: 26
# generation 2163 Max fitness: 25
# generation 2164 Max fitness: 25
# generation 2165 Max fitness: 25
# generation 2166 Max fitness: 25
# generation 2167 Max fitness: 24
# generation 2168 Max fitness: 25
# generation 2169 Max fitness: 25
# generation 2170 Max fitness: 24
# generation 2171 Max fitness: 26
# generation 2172 Max fitness: 24
# generation 2173 Max fitness: 26
# generation 2174 Max fitness: 25
# generation 2175 Max fitness: 24
# generation 2176 Max fitness: 24
# generation 2177 Max fitness: 24
# generation 2178 Max fitness: 23
# generation 2179 Max fitness: 24
# generation 2180 Max fitness: 24
# generation 2181 Max fitness: 25
# generation 2182 Max fitness: 23
# generation 2183 Max fitness: 25
# generation 2184 Max fitness: 25
# generation 2185 Max fitness: 25
# generation 2186 Max fitness: 26
# generation 2187 Max fitness: 25
# generation 2188 Max fitness: 26
# generation 2189 Max fitness: 24
# generation 2190 Max fitness: 25
# generation 2191 Max fitness: 25
# generation 2192 Max fitness: 24
# generation 2193 Max fitness: 25
# generation 2194 Max fitness: 26
# generation 2195 Max fitness: 25
# generation 2196 Max fitness: 26
# generation 2197 Max fitness: 25
# generation 2198 Max fitness: 25
# generation 2199 Max fitness: 25
# generation 2200 Max fitness: 25
# generation 2201 Max fitness: 24
# generation 2202 Max fitness: 24
# generation 2203 Max fitness: 24
# generation 2204 Max fitness: 24
# generation 2205 Max fitness: 25
# generation 2206 Max fitness: 25
# generation 2207 Max fitness: 25
# generation 2208 Max fitness: 25
# generation 2209 Max fitness: 26
# generation 2210 Max fitness: 25
# generation 2211 Max fitness: 25
# generation 2212 Max fitness: 25
# generation 2213 Max fitness: 25
# generation 2214 Max fitness: 25
# generation 2215 Max fitness: 25
# generation 2216 Max fitness: 25
# generation 2217 Max fitness: 24
# generation 2218 Max fitness: 24
# generation 2219 Max fitness: 25
# generation 2220 Max fitness: 26
# generation 2221 Max fitness: 25
# generation 2222 Max fitness: 25
# generation 2223 Max fitness: 25
# generation 2224 Max fitness: 25
# generation 2225 Max fitness: 25
# generation 2226 Max fitness: 26
# generation 2227 Max fitness: 25
# generation 2228 Max fitness: 25
# generation 2229 Max fitness: 25
# generation 2230 Max fitness: 26
# generation 2231 Max fitness: 26
# generation 2232 Max fitness: 25
# generation 2233 Max fitness: 25
# generation 2234 Max fitness: 25
# generation 2235 Max fitness: 25
# generation 2236 Max fitness: 25
# generation 2237 Max fitness: 25
# generation 2238 Max fitness: 24
# generation 2239 Max fitness: 25
# generation 2240 Max fitness: 24
# generation 2241 Max fitness: 23
# generation 2242 Max fitness: 25
# generation 2243 Max fitness: 26
# generation 2244 Max fitness: 24
# generation 2245 Max fitness: 25
# generation 2246 Max fitness: 25
# generation 2247 Max fitness: 25
# generation 2248 Max fitness: 26
# generation 2249 Max fitness: 25
# generation 2250 Max fitness: 24
# generation 2251 Max fitness: 24
# generation 2252 Max fitness: 26
# generation 2253 Max fitness: 24
# generation 2254 Max fitness: 25
# generation 2255 Max fitness: 25
# generation 2256 Max fitness: 25
# generation 2257 Max fitness: 25
# generation 2258 Max fitness: 25
# generation 2259 Max fitness: 25
# generation 2260 Max fitness: 24
# generation 2261 Max fitness: 24
# generation 2262 Max fitness: 25
# generation 2263 Max fitness: 24
# generation 2264 Max fitness: 25
# generation 2265 Max fitness: 24
# generation 2266 Max fitness: 24
# generation 2267 Max fitness: 24
# generation 2268 Max fitness: 24
# generation 2269 Max fitness: 25
# generation 2270 Max fitness: 25
# generation 2271 Max fitness: 25
# generation 2272 Max fitness: 24
# generation 2273 Max fitness: 26
# generation 2274 Max fitness: 24
# generation 2275 Max fitness: 25
# generation 2276 Max fitness: 26
# generation 2277 Max fitness: 25
# generation 2278 Max fitness: 24
# generation 2279 Max fitness: 25
# generation 2280 Max fitness: 25
# generation 2281 Max fitness: 26
# generation 2282 Max fitness: 26
# generation 2283 Max fitness: 25
# generation 2284 Max fitness: 25
# generation 2285 Max fitness: 26
# generation 2286 Max fitness: 24
# generation 2287 Max fitness: 24
# generation 2288 Max fitness: 25
# generation 2289 Max fitness: 25
# generation 2290 Max fitness: 26
# generation 2291 Max fitness: 24
# generation 2292 Max fitness: 24
# generation 2293 Max fitness: 24
# generation 2294 Max fitness: 23
# generation 2295 Max fitness: 24
# generation 2296 Max fitness: 26
# generation 2297 Max fitness: 26
# generation 2298 Max fitness: 24
# generation 2299 Max fitness: 25
# generation 2300 Max fitness: 25
# generation 2301 Max fitness: 26
# generation 2302 Max fitness: 25
# generation 2303 Max fitness: 25
# generation 2304 Max fitness: 25
# generation 2305 Max fitness: 25
# generation 2306 Max fitness: 26
# generation 2307 Max fitness: 24
# generation 2308 Max fitness: 25
# generation 2309 Max fitness: 26
# generation 2310 Max fitness: 24
# generation 2311 Max fitness: 25
# generation 2312 Max fitness: 25
# generation 2313 Max fitness: 24
# generation 2314 Max fitness: 24
# generation 2315 Max fitness: 24
# generation 2316 Max fitness: 24
# generation 2317 Max fitness: 24
# generation 2318 Max fitness: 25
# generation 2319 Max fitness: 25
# generation 2320 Max fitness: 24
# generation 2321 Max fitness: 24
# generation 2322 Max fitness: 24
# generation 2323 Max fitness: 24
# generation 2324 Max fitness: 23
# generation 2325 Max fitness: 25
# generation 2326 Max fitness: 25
# generation 2327 Max fitness: 25
# generation 2328 Max fitness: 24
# generation 2329 Max fitness: 25
# generation 2330 Max fitness: 26
# generation 2331 Max fitness: 27
# generation 2332 Max fitness: 25
# generation 2333 Max fitness: 25
# generation 2334 Max fitness: 25
# generation 2335 Max fitness: 26
# generation 2336 Max fitness: 26
# generation 2337 Max fitness: 24
# generation 2338 Max fitness: 25
# generation 2339 Max fitness: 25
# generation 2340 Max fitness: 25
# generation 2341 Max fitness: 25
# generation 2342 Max fitness: 26
# generation 2343 Max fitness: 26
# generation 2344 Max fitness: 25
# generation 2345 Max fitness: 25
# generation 2346 Max fitness: 25
# generation 2347 Max fitness: 25
# generation 2348 Max fitness: 26
# generation 2349 Max fitness: 25
# generation 2350 Max fitness: 25
# generation 2351 Max fitness: 25
# generation 2352 Max fitness: 25
# generation 2353 Max fitness: 25
# generation 2354 Max fitness: 25
# generation 2355 Max fitness: 25
# generation 2356 Max fitness: 24
# generation 2357 Max fitness: 23
# generation 2358 Max fitness: 25
# generation 2359 Max fitness: 25
# generation 2360 Max fitness: 26
# generation 2361 Max fitness: 25
# generation 2362 Max fitness: 25
# generation 2363 Max fitness: 26
# generation 2364 Max fitness: 26
# generation 2365 Max fitness: 26
# generation 2366 Max fitness: 25
# generation 2367 Max fitness: 25
# generation 2368 Max fitness: 25
# generation 2369 Max fitness: 24
# generation 2370 Max fitness: 25
# generation 2371 Max fitness: 25
# generation 2372 Max fitness: 24
# generation 2373 Max fitness: 26
# generation 2374 Max fitness: 26
# generation 2375 Max fitness: 25
# generation 2376 Max fitness: 25
# generation 2377 Max fitness: 26
# generation 2378 Max fitness: 25
# generation 2379 Max fitness: 25
# generation 2380 Max fitness: 24
# generation 2381 Max fitness: 25
# generation 2382 Max fitness: 26
# generation 2383 Max fitness: 24
# generation 2384 Max fitness: 25
# generation 2385 Max fitness: 26
# generation 2386 Max fitness: 26
# generation 2387 Max fitness: 25
# generation 2388 Max fitness: 26
# generation 2389 Max fitness: 24
# generation 2390 Max fitness: 24
# generation 2391 Max fitness: 26
# generation 2392 Max fitness: 27
# generation 2393 Max fitness: 26
# generation 2394 Max fitness: 24
# generation 2395 Max fitness: 27
# generation 2396 Max fitness: 24
# generation 2397 Max fitness: 26
# generation 2398 Max fitness: 24
# generation 2399 Max fitness: 23
# generation 2400 Max fitness: 23
# generation 2401 Max fitness: 25
# generation 2402 Max fitness: 25
# generation 2403 Max fitness: 25
# generation 2404 Max fitness: 25
# generation 2405 Max fitness: 25
# generation 2406 Max fitness: 24
# generation 2407 Max fitness: 25
# generation 2408 Max fitness: 25
# generation 2409 Max fitness: 25
# generation 2410 Max fitness: 25
# generation 2411 Max fitness: 24
# generation 2412 Max fitness: 24
# generation 2413 Max fitness: 24
# generation 2414 Max fitness: 25
# generation 2415 Max fitness: 25
# generation 2416 Max fitness: 24
# generation 2417 Max fitness: 26
# generation 2418 Max fitness: 25
# generation 2419 Max fitness: 24
# generation 2420 Max fitness: 25
# generation 2421 Max fitness: 25
# generation 2422 Max fitness: 25
# generation 2423 Max fitness: 24
# generation 2424 Max fitness: 25
# generation 2425 Max fitness: 24
# generation 2426 Max fitness: 25
# generation 2427 Max fitness: 26
# generation 2428 Max fitness: 25
# generation 2429 Max fitness: 25
# generation 2430 Max fitness: 24
# generation 2431 Max fitness: 24
# generation 2432 Max fitness: 26
# generation 2433 Max fitness: 24
# generation 2434 Max fitness: 25
# generation 2435 Max fitness: 24
# generation 2436 Max fitness: 24
# generation 2437 Max fitness: 26
# generation 2438 Max fitness: 25
# generation 2439 Max fitness: 25
# generation 2440 Max fitness: 25
# generation 2441 Max fitness: 25
# generation 2442 Max fitness: 25
# generation 2443 Max fitness: 25
# generation 2444 Max fitness: 25
# generation 2445 Max fitness: 25
# generation 2446 Max fitness: 25
# generation 2447 Max fitness: 25
# generation 2448 Max fitness: 25
# generation 2449 Max fitness: 25
# generation 2450 Max fitness: 26
# generation 2451 Max fitness: 25
# generation 2452 Max fitness: 26
# generation 2453 Max fitness: 24
# generation 2454 Max fitness: 23
# generation 2455 Max fitness: 24
# generation 2456 Max fitness: 25
# generation 2457 Max fitness: 24
# generation 2458 Max fitness: 25
# generation 2459 Max fitness: 25
# generation 2460 Max fitness: 25
# generation 2461 Max fitness: 26
# generation 2462 Max fitness: 24
# generation 2463 Max fitness: 24
# generation 2464 Max fitness: 25
# generation 2465 Max fitness: 25
# generation 2466 Max fitness: 25
# generation 2467 Max fitness: 25
# generation 2468 Max fitness: 24
# generation 2469 Max fitness: 25
# generation 2470 Max fitness: 24
# generation 2471 Max fitness: 26
# generation 2472 Max fitness: 25
# generation 2473 Max fitness: 25
# generation 2474 Max fitness: 25
# generation 2475 Max fitness: 25
# generation 2476 Max fitness: 25
# generation 2477 Max fitness: 26
# generation 2478 Max fitness: 26
# generation 2479 Max fitness: 25
# generation 2480 Max fitness: 26
# generation 2481 Max fitness: 25
# generation 2482 Max fitness: 25
# generation 2483 Max fitness: 24
# generation 2484 Max fitness: 26
# generation 2485 Max fitness: 24
# generation 2486 Max fitness: 24
# generation 2487 Max fitness: 24
# generation 2488 Max fitness: 24
# generation 2489 Max fitness: 25
# generation 2490 Max fitness: 25
# generation 2491 Max fitness: 25
# generation 2492 Max fitness: 24
# generation 2493 Max fitness: 23
# generation 2494 Max fitness: 23
# generation 2495 Max fitness: 25
# generation 2496 Max fitness: 24
# generation 2497 Max fitness: 25
# generation 2498 Max fitness: 24
# generation 2499 Max fitness: 25
# generation 2500 Max fitness: 25
# generation 2501 Max fitness: 25
# generation 2502 Max fitness: 24
# generation 2503 Max fitness: 25
# generation 2504 Max fitness: 25
# generation 2505 Max fitness: 24
# generation 2506 Max fitness: 26
# generation 2507 Max fitness: 25
# generation 2508 Max fitness: 24
# generation 2509 Max fitness: 25
# generation 2510 Max fitness: 25
# generation 2511 Max fitness: 25
# generation 2512 Max fitness: 25
# generation 2513 Max fitness: 25
# generation 2514 Max fitness: 25
# generation 2515 Max fitness: 25
# generation 2516 Max fitness: 25
# generation 2517 Max fitness: 25
# generation 2518 Max fitness: 25
# generation 2519 Max fitness: 26
# generation 2520 Max fitness: 25
# generation 2521 Max fitness: 26
# generation 2522 Max fitness: 25
# generation 2523 Max fitness: 25
# generation 2524 Max fitness: 25
# generation 2525 Max fitness: 25
# generation 2526 Max fitness: 25
# generation 2527 Max fitness: 24
# generation 2528 Max fitness: 25
# generation 2529 Max fitness: 24
# generation 2530 Max fitness: 25
# generation 2531 Max fitness: 25
# generation 2532 Max fitness: 26
# generation 2533 Max fitness: 24
# generation 2534 Max fitness: 25
# generation 2535 Max fitness: 25
# generation 2536 Max fitness: 25
# generation 2537 Max fitness: 25
# generation 2538 Max fitness: 25
# generation 2539 Max fitness: 25
# generation 2540 Max fitness: 25
# generation 2541 Max fitness: 24
# generation 2542 Max fitness: 25
# generation 2543 Max fitness: 25
# generation 2544 Max fitness: 25
# generation 2545 Max fitness: 25
# generation 2546 Max fitness: 25
# generation 2547 Max fitness: 25
# generation 2548 Max fitness: 27
# generation 2549 Max fitness: 25
# generation 2550 Max fitness: 26
# generation 2551 Max fitness: 24
# generation 2552 Max fitness: 24
# generation 2553 Max fitness: 24
# generation 2554 Max fitness: 25
# generation 2555 Max fitness: 25
# generation 2556 Max fitness: 25
# generation 2557 Max fitness: 24
# generation 2558 Max fitness: 25
# generation 2559 Max fitness: 25
# generation 2560 Max fitness: 26
# generation 2561 Max fitness: 25
# generation 2562 Max fitness: 25
# generation 2563 Max fitness: 25
# generation 2564 Max fitness: 25
# generation 2565 Max fitness: 26
# generation 2566 Max fitness: 25
# generation 2567 Max fitness: 25
# generation 2568 Max fitness: 25
# generation 2569 Max fitness: 26
# generation 2570 Max fitness: 25
# generation 2571 Max fitness: 25
# generation 2572 Max fitness: 25
# generation 2573 Max fitness: 25
# generation 2574 Max fitness: 23
# generation 2575 Max fitness: 26
# generation 2576 Max fitness: 25
# generation 2577 Max fitness: 26
# generation 2578 Max fitness: 24
# generation 2579 Max fitness: 24
# generation 2580 Max fitness: 25
# generation 2581 Max fitness: 24
# generation 2582 Max fitness: 25
# generation 2583 Max fitness: 25
# generation 2584 Max fitness: 25
# generation 2585 Max fitness: 25
# generation 2586 Max fitness: 24
# generation 2587 Max fitness: 24
# generation 2588 Max fitness: 25
# generation 2589 Max fitness: 24
# generation 2590 Max fitness: 26
# generation 2591 Max fitness: 24
# generation 2592 Max fitness: 24
# generation 2593 Max fitness: 25
# generation 2594 Max fitness: 24
# generation 2595 Max fitness: 25
# generation 2596 Max fitness: 24
# generation 2597 Max fitness: 24
# generation 2598 Max fitness: 24
# generation 2599 Max fitness: 26
# generation 2600 Max fitness: 26
# generation 2601 Max fitness: 25
# generation 2602 Max fitness: 25
# generation 2603 Max fitness: 24
# generation 2604 Max fitness: 25
# generation 2605 Max fitness: 25
# generation 2606 Max fitness: 24
# generation 2607 Max fitness: 25
# generation 2608 Max fitness: 26
# generation 2609 Max fitness: 26
# generation 2610 Max fitness: 24
# generation 2611 Max fitness: 25
# generation 2612 Max fitness: 25
# generation 2613 Max fitness: 25
# generation 2614 Max fitness: 24
# generation 2615 Max fitness: 25
# generation 2616 Max fitness: 24
# generation 2617 Max fitness: 25
# generation 2618 Max fitness: 24
# generation 2619 Max fitness: 25
# generation 2620 Max fitness: 25
# generation 2621 Max fitness: 25
# generation 2622 Max fitness: 24
# Parents::
# Generation: 2622
# Fitness: 21
# [4, 6, 3, 7, 1, 6, 5, 3]
# ▧ ☐ ▧ ☐ ♛ ☐ ▧ ☐
# ☐ ▧ ☐ ▧ ☐ ▧ ☐ ▧
# ▧ ☐ ♛ ☐ ▧ ☐ ▧ ♛
# ♛ ▧ ☐ ▧ ☐ ▧ ☐ ▧
# ▧ ☐ ▧ ☐ ▧ ☐ ♛ ☐
# ☐ ♛ ☐ ▧ ☐ ♛ ☐ ▧
# ▧ ☐ ▧ ♛ ▧ ☐ ▧ ☐
# ☐ ▧ ☐ ▧ ☐ ▧ ☐ ▧
#
# Generation: 2622
# Fitness: 22
# [5, 8, 3, 6, 1, 7, 5, 3]
# ▧ ☐ ▧ ☐ ♛ ☐ ▧ ☐
# ☐ ▧ ☐ ▧ ☐ ▧ ☐ ▧
# ▧ ☐ ♛ ☐ ▧ ☐ ▧ ♛
# ☐ ▧ ☐ ▧ ☐ ▧ ☐ ▧
# ♛ ☐ ▧ ☐ ▧ ☐ ♛ ☐
# ☐ ▧ ☐ ♛ ☐ ▧ ☐ ▧
# ▧ ☐ ▧ ☐ ▧ ♛ ▧ ☐
# ☐ ♛ ☐ ▧ ☐ ▧ ☐ ▧
#
# Solution state:
# Generation: 2623
# Fitness: 28
# [4, 6, 8, 3, 1, 7, 5, 2]
# ▧ ☐ ▧ ☐ ♛ ☐ ▧ ☐
# ☐ ▧ ☐ ▧ ☐ ▧ ☐ ♛
# ▧ ☐ ▧ ♛ ▧ ☐ ▧ ☐
# ♛ ▧ ☐ ▧ ☐ ▧ ☐ ▧
# ▧ ☐ ▧ ☐ ▧ ☐ ♛ ☐
# ☐ ♛ ☐ ▧ ☐ ▧ ☐ ▧
# ▧ ☐ ▧ ☐ ▧ ♛ ▧ ☐
# ☐ ▧ ♛ ▧ ☐ ▧ ☐ ▧
